# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # `Reranking `
# in large language models (LLMs) refers to the process of reordering or reprioritizing a set of candidate responses, results, or outputs generated by the model to select the best or most relevant one.
